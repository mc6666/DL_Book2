# %% [markdown]
# # Gymnasium 探索

# %% [markdown]
# ## 載入套件

# %%
import gymnasium as gym

# %% [markdown]
# ## 顯示已註冊的遊戲

# %%
all_envs = gym.pprint_registry()
print(all_envs)
# Out:
# ===== classic_control =====
# Acrobot-v1             CartPole-v0            CartPole-v1
# MountainCar-v0         MountainCarContinuous-v0 Pendulum-v1
# ===== phys2d =====
# phys2d/CartPole-v0     phys2d/CartPole-v1     phys2d/Pendulum-v0
# ===== box2d =====
# BipedalWalker-v3       BipedalWalkerHardcore-v3 CarRacing-v3
# LunarLander-v3         LunarLanderContinuous-v3
# ===== toy_text =====
# Blackjack-v1           CliffWalking-v0        FrozenLake-v1
# FrozenLake8x8-v1       Taxi-v3
# ===== tabular =====
# tabular/Blackjack-v0   tabular/CliffWalking-v0
# ===== mujoco =====
# Ant-v2                 Ant-v3                 Ant-v4
# Ant-v5                 HalfCheetah-v2         HalfCheetah-v3
# HalfCheetah-v4         HalfCheetah-v5         Hopper-v2
# Hopper-v3              Hopper-v4              Hopper-v5
# Humanoid-v2            Humanoid-v3            Humanoid-v4
# Humanoid-v5            HumanoidStandup-v2     HumanoidStandup-v4
# HumanoidStandup-v5     InvertedDoublePendulum-v2 InvertedDoublePendulum-v4
# InvertedDoublePendulum-v5 InvertedPendulum-v2    InvertedPendulum-v4
# InvertedPendulum-v5    Pusher-v2              Pusher-v4
# Pusher-v5              Reacher-v2             Reacher-v4
# Reacher-v5             Swimmer-v2             Swimmer-v3
# Swimmer-v4             Swimmer-v5             Walker2d-v2
# Walker2d-v3            Walker2d-v4            Walker2d-v5
# ===== None =====
# GymV21Environment-v0   GymV26Environment-v0
# None

# %%
gym.envs.registry.keys()
# Out:
# dict_keys(['CartPole-v0', 'CartPole-v1', 'MountainCar-v0', 'MountainCarContinuous-v0', 'Pendulum-v1', 'Acrobot-v1', 'phys2d/CartPole-v0', 'phys2d/CartPole-v1', 'phys2d/Pendulum-v0', 'LunarLander-v3', 'LunarLanderContinuous-v3', 'BipedalWalker-v3', 'BipedalWalkerHardcore-v3', 'CarRacing-v3', 'Blackjack-v1', 'FrozenLake-v1', 'FrozenLake8x8-v1', 'CliffWalking-v0', 'Taxi-v3', 'tabular/Blackjack-v0', 'tabular/CliffWalking-v0', 'Reacher-v2', 'Reacher-v4', 'Reacher-v5', 'Pusher-v2', 'Pusher-v4', 'Pusher-v5', 'InvertedPendulum-v2', 'InvertedPendulum-v4', 'InvertedPendulum-v5', 'InvertedDoublePendulum-v2', 'InvertedDoublePendulum-v4', 'InvertedDoublePendulum-v5', 'HalfCheetah-v2', 'HalfCheetah-v3', 'HalfCheetah-v4', 'HalfCheetah-v5', 'Hopper-v2', 'Hopper-v3', 'Hopper-v4', 'Hopper-v5', 'Swimmer-v2', 'Swimmer-v3', 'Swimmer-v4', 'Swimmer-v5', 'Walker2d-v2', 'Walker2d-v3', 'Walker2d-v4', 'Walker2d-v5', 'Ant-v2', 'Ant-v3', 'Ant-v4', 'Ant-v5', 'Humanoid-v2', 'Humanoid-v3', 'Humanoid-v4', 'Humanoid-v5', 'HumanoidStandup-v2', 'HumanoidStandup-v4', 'HumanoidStandup-v5', 'GymV21Environment-v0', 'GymV26Environment-v0'])

# %% [markdown]
# ## 列出環境詳細資訊

# %%
import pandas as pd
space_names = ['觀測空間', '行動空間',] # '獎勵範圍', '最大步數']
df = pd.DataFrame(columns=space_names)

env_specs = gym.envs.registry
i=0
for env_id in gym.envs.registry.keys():
    i+=1
    try:
        env = gym.make(env_id)
        observation_space = env.observation_space
        action_space = env.action_space
        df.loc[env_id] = [observation_space, action_space] 
        #, reward_range, max_episode_steps]
    except:
        pass

df.reset_index(level=0, inplace=True)  
col=list(df.columns)
col[0]='name'
df.columns=col
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
display(df)
# Out:
#                          name                                               觀測空間                                    行動空間
# 0                 CartPole-v0  Box([-4.8               -inf -0.41887903      ...                             Discrete(2)
# 1                 CartPole-v1  Box([-4.8               -inf -0.41887903      ...                             Discrete(2)
# 2              MountainCar-v0     Box([-1.2  -0.07], [0.6  0.07], (2,), float32)                             Discrete(3)
# 3    MountainCarContinuous-v0     Box([-1.2  -0.07], [0.6  0.07], (2,), float32)           Box(-1.0, 1.0, (1,), float32)
# 4                 Pendulum-v1      Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)           Box(-2.0, 2.0, (1,), float32)
# 5                  Acrobot-v1  Box([ -1.        -1.        -1.        -1.    ...                             Discrete(3)
# 6          phys2d/CartPole-v0                      Box(-inf, inf, (4,), float32)                             Discrete(2)
# 7          phys2d/CartPole-v1                      Box(-inf, inf, (4,), float32)                             Discrete(2)
# 8          phys2d/Pendulum-v0                      Box(-inf, inf, (3,), float32)           Box(-2.0, 2.0, (1,), float32)
# 9              LunarLander-v3  Box([ -2.5        -2.5       -10.        -10. ...                             Discrete(4)
# 10   LunarLanderContinuous-v3  Box([ -2.5        -2.5       -10.        -10. ...           Box(-1.0, 1.0, (2,), float32)
# 11           BipedalWalker-v3  Box([-3.1415927 -5.        -5.        -5.     ...           Box(-1.0, 1.0, (4,), float32)
# 12   BipedalWalkerHardcore-v3  Box([-3.1415927 -5.        -5.        -5.     ...           Box(-1.0, 1.0, (4,), float32)
# 13               CarRacing-v3                    Box(0, 255, (96, 96, 3), uint8)  Box([-1.  0.  0.], 1.0, (3,), float32)
# 14               Blackjack-v1          (Discrete(32), Discrete(11), Discrete(2))                             Discrete(2)
# 15              FrozenLake-v1                                       Discrete(16)                             Discrete(4)
# 16           FrozenLake8x8-v1                                       Discrete(64)                             Discrete(4)
# 17            CliffWalking-v0                                       Discrete(48)                             Discrete(4)
# 18                    Taxi-v3                                      Discrete(500)                             Discrete(6)
# 19       tabular/Blackjack-v0              Box([1 1 0], [32 11  1], (3,), int32)                             Discrete(2)
# 20    tabular/CliffWalking-v0                            Box(0, 47, (1,), int32)                  Box(0, 3, (1,), int32)
# 21                 Reacher-v4                     Box(-inf, inf, (11,), float64)           Box(-1.0, 1.0, (2,), float32)
# 22                 Reacher-v5                     Box(-inf, inf, (10,), float64)           Box(-1.0, 1.0, (2,), float32)
# 23                  Pusher-v5                     Box(-inf, inf, (23,), float64)           Box(-2.0, 2.0, (7,), float32)
# 24        InvertedPendulum-v4                      Box(-inf, inf, (4,), float64)           Box(-3.0, 3.0, (1,), float32)
# 25        InvertedPendulum-v5                      Box(-inf, inf, (4,), float64)           Box(-3.0, 3.0, (1,), float32)
# 26  InvertedDoublePendulum-v4                     Box(-inf, inf, (11,), float64)           Box(-1.0, 1.0, (1,), float32)
# 27  InvertedDoublePendulum-v5                      Box(-inf, inf, (9,), float64)           Box(-1.0, 1.0, (1,), float32)
# 28             HalfCheetah-v4                     Box(-inf, inf, (17,), float64)           Box(-1.0, 1.0, (6,), float32)
# 29             HalfCheetah-v5                     Box(-inf, inf, (17,), float64)           Box(-1.0, 1.0, (6,), float32)
# 30                  Hopper-v4                     Box(-inf, inf, (11,), float64)           Box(-1.0, 1.0, (3,), float32)
# 31                  Hopper-v5                     Box(-inf, inf, (11,), float64)           Box(-1.0, 1.0, (3,), float32)
# 32                 Swimmer-v4                      Box(-inf, inf, (8,), float64)           Box(-1.0, 1.0, (2,), float32)
# 33                 Swimmer-v5                      Box(-inf, inf, (8,), float64)           Box(-1.0, 1.0, (2,), float32)
# 34                Walker2d-v4                     Box(-inf, inf, (17,), float64)           Box(-1.0, 1.0, (6,), float32)
# 35                Walker2d-v5                     Box(-inf, inf, (17,), float64)           Box(-1.0, 1.0, (6,), float32)
# 36                     Ant-v4                     Box(-inf, inf, (27,), float64)           Box(-1.0, 1.0, (8,), float32)
# 37                     Ant-v5                    Box(-inf, inf, (105,), float64)           Box(-1.0, 1.0, (8,), float32)
# 38                Humanoid-v4                    Box(-inf, inf, (376,), float64)          Box(-0.4, 0.4, (17,), float32)
# 39                Humanoid-v5                    Box(-inf, inf, (348,), float64)          Box(-0.4, 0.4, (17,), float32)
# 40         HumanoidStandup-v4                    Box(-inf, inf, (376,), float64)          Box(-0.4, 0.4, (17,), float32)
# 41         HumanoidStandup-v5                    Box(-inf, inf, (348,), float64)          Box(-0.4, 0.4, (17,), float32)

# %% [markdown]
# ## 進一步顯示行動及觀測空間

# %%
# 載入 木棒台車(CartPole) 遊戲
env = gym.make("CartPole-v1")

# 環境的資訊
print(env.action_space)
print(env.observation_space)
print('observation_space 範圍：')
print(env.observation_space.high)
print(env.observation_space.low)
# Out:
# Discrete(2)
# Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# observation_space 範圍：
# [4.8               inf 0.41887903        inf]
# [-4.8               -inf -0.41887903        -inf]

# %%
# 載入 21點(Blackjack-v0) 遊戲
env = gym.make("Blackjack-v1")

# 環境的資訊
print(env.action_space)
print(env.observation_space)
# Out:
# Discrete(2)
# Tuple(Discrete(32), Discrete(11), Discrete(2))

# %% [markdown]
# ## 實驗登陸月球(LunarLander)遊戲，並顯示畫面

# %%
# render_mode="human"：顯示畫面，render_mode="rgb_array"：不顯示畫面
env = gym.make("LunarLander-v3", render_mode="human")

for _ in range(3):    
    # 比賽重置
    observation, info = env.reset()
    episode_over = False
    while not episode_over:
        # 隨機行動
        action = env.action_space.sample()  
        # 觸動下一步
        observation, reward, terminated, truncated, info = env.step(action)
        # 判斷比賽回合是否結束
        episode_over = terminated or truncated

env.close()

# %% [markdown]
# ## 記錄執行過程

# %%
# 載入 木棒台車(CartPole) 遊戲
env = gym.make("CartPole-v1")

# 比賽回合結束，重置
observation, info = env.reset()
# 將環境資訊寫入日誌檔
with open("CartPole_random.log", "w", encoding='utf8') as f:
    # 執行 1000 次行動
    for _ in range(1000):
        # 更新畫面
        env.render()
        # 隨機行動
        action = env.action_space.sample() 
        # 觸動下一步
        observation, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        # 寫入資訊
        f.write(f"action={action}, observation={observation}," +  
                 f"reward={reward}, done={done}, info={info}\n")
        # 比賽回合結束，重置
        if done:
            observation, info = env.reset()
env.close()
