# %% [markdown]
# # 中央極限定理

# %% [markdown]
# ## 繪製常態分配(Normal Distribution)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# 觀察值範圍
z1, z2 = -4, 4

# 樣本點
x = np.arange(z1, z2, 0.001) 
y = norm.pdf(x,0,1)

# 繪圖
plt.figure(figsize=(6,4))
plt.plot(x,y,'black')

# 對平均數的pdf畫虛線
plt.axhline(.4, c='r', linestyle=':')

# 填色
plt.fill_between(x,y,0, alpha=0.3, color='b')
plt.show()

# %% [markdown]
# ## 常態分配的各種信賴區間

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# 觀察值範圍
z1, z2 = -4, 4

# 樣本點
x = np.arange(z1, z2, 0.001) 
y = norm.pdf(x,0,1)

# 繪圖
plt.figure(figsize=(6,4))
plt.plot(x,y,'black')


# 設定圖形屬性
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()

# 對正負1、2、3倍標準差畫虛線
plt.axvline(-3, c='r', linestyle=':')
plt.axvline(3, c='r', linestyle=':')
plt.axvline(-2, c='g', linestyle=':')
plt.axvline(2, c='g', linestyle=':')
plt.axvline(-1, c='b', linestyle=':')
plt.axvline(1, c='b', linestyle=':')

# 1 倍標準差機率
plt.annotate(text='', xy=(-1,0.25), xytext=(1,0.25), arrowprops=dict(arrowstyle='<->'))
plt.annotate(text='68.3%', xy=(0,0.26), xytext=(0,0.26))
# 2 倍標準差機率
plt.annotate(text='', xy=(-2,0.05), xytext=(2,0.05), arrowprops=dict(arrowstyle='<->'))
plt.annotate(text='95.4%', xy=(0,0.06), xytext=(0,0.06))
# 3 倍標準差機率
plt.annotate(text='', xy=(-3,0.01), xytext=(3,0.01), arrowprops=dict(arrowstyle='<->'))
plt.annotate(text='99.7%', xy=(0,0.02), xytext=(0,0.02))

# 填色
plt.fill_between(x,y,0, alpha=0.3, color='b')
plt.show()

# %% [markdown]
# ## 利用隨機亂數產生常態分配的樣本

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# 產生隨機亂數的樣本
mu = 5     # 平均數
sigma = 2  # 標準差
n = 10000  # 樣本數
data = np.random.normal(mu, sigma, n)

cl = .95   #信賴水準(Confidence Level)

# 計算信賴區間
m = data.mean()
sd = data.std()
y1 = norm.interval(cl, m, sd)
print(f'平均數={m}, 標準差={sd}, 信賴區間={y1}')
# Out:
# 平均數=4.998262174123385, 標準差=1.9999568825562954, 信賴區間=(1.0784187136800427, 8.918105634566727)

# %% [markdown]
# ## 繪圖並標記信賴區間

# %%
import seaborn as sns

# 直方圖
plt.figure(figsize=(6,4))
sns.kdeplot(data)

# 畫信賴區間
plt.axvline(y1[0], c='r', linestyle=':')
plt.axvline(y1[1], c='r', linestyle=':')

# 標示 95%
plt.annotate(text='', xy=(y1[0],0.025), xytext=(y1[1],0.025), 
             arrowprops=dict(arrowstyle='<->'))
plt.annotate(text='95%', xy=(mu,0.03), xytext=(mu,0.03))

plt.show()

# %% [markdown]
# ## 利用隨機亂數產生二項分配的樣本

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import binom

# 產生隨機亂數的樣本
trials = 1  # 實驗次數
p = 0.5     # 出現正面的機率
n = 10000   # 樣本數
data = np.random.binomial(trials, p, n)

cl = .95   #信賴水準(Confidence Level)

# 計算信賴區間
m = data.mean()
sd = data.std()
y1 = binom.interval(cl, n, m)
print(f'平均數={m}, 標準差={sd}, 信賴區間={y1}')
# Out:
# 平均數=0.5017, 標準差=0.4999971099916478, 信賴區間=(4919.0, 5115.0)

# %%
(p*(1-p))**.5
# Out:
# 0.5

# %% [markdown]
# ## 繪圖驗證是否近似常態分配。

# %%
# 直方圖
plt.figure(figsize=(6,4))
sns.histplot(data, bins=20)
plt.show()

# %%
(p*(1-p) / trials) **.5
# Out:
# 0.05
