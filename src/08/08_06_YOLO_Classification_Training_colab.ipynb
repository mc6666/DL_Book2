# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.0/887.0 kB 31.8 MB/s eta 0:00:00
# ...

# %%
# !yolo classify train data=mnist160 model=yolo11n-cls.yaml epochs=100 imgsz=64
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLO11n-cls summary: 151 layers, 1,633,584 parameters, 1,633,584 gradients, 3.3 GFLOPs
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo classify val model=runs/classify/train/weights/best.pt data=mnist160 split=test
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n-cls summary (fused): 112 layers, 1,538,834 parameters, 0 gradients, 3.2 GFLOPs
# train: /content/datasets/mnist160/train... found 80 images in 10 classes ✅
# val: None...
# test: /content/datasets/mnist160/test... found 80 images in 10 classes ✅
# test: Scanning /content/datasets/mnist160/test... 80 images, 0 corrupt: 100% 80/80 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:00<00:00, 14.97it/s]
#                    all       0.75       0.95
# Speed: 0.0ms preprocess, 2.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo classify predict model=runs/classify/train/weights/best.pt source='/content/datasets/mnist160/test/9/214.png'
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n-cls summary (fused): 112 layers, 1,538,834 parameters, 0 gradients, 3.2 GFLOPs
#
# image 1/1 /content/datasets/mnist160/test/9/214.png: 64x64 9 0.96, 7 0.03, 8 0.01, 4 0.00, 3 0.00, 6.5ms
# Speed: 3.7ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
