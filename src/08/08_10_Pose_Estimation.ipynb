# %% [markdown]
# # YOLO Pose Estimation 測試

# %% [markdown]
# ## # 載入套件

# %%
from ultralytics import YOLO

# %% [markdown]
# ## 建立YOLO物件並載入YOLO權重檔

# %%
model = YOLO("yolo11n-pose.pt")

# %% [markdown]
# ## 辨識

# %%
results = model("https://ultralytics.com/images/bus.jpg")
results
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 F:\0_AI\Books\Tensorflow\00_V2\src\08\bus.jpg: 640x480 4 persons, 50.9ms
# Speed: 3.0ms preprocess, 50.9ms inference, 69.0ms postprocess per image at shape (1, 3, 640, 480)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'person'}
#  obb: None
#  orig_img: array([[[119, 146, 172],
#          [121, 148, 174],
#          [122, 152, 177],
#          ...,
#          [161, 171, 188],
#          [160, 170, 187],
#          [160, 170, 187]],
#
#         [[120, 147, 173],
#          [122, 149, 175],
#          [123, 153, 178],
#          ...,
#          [161, 171, 188],
#          [160, 170, 187],
#          [160, 170, 187]],
#
#         [[123, 150, 176],
#          [124, 151, 177],
#          [125, 155, 180],
#          ...,
#          [161, 171, 188],
#          [160, 170, 187],
#          [160, 170, 187]],
#
#         ...,
#
#         [[183, 182, 186],
#          [179, 178, 182],
#          [180, 179, 183],
#          ...,
#          [121, 111, 117],
#          [113, 103, 109],
#          [115, 105, 111]],
#
#         [[165, 164, 168],
#          [173, 172, 176],
#          [187, 186, 190],
#          ...,
#          [102,  92,  98],
#          [101,  91,  97],
#          [103,  93,  99]],
#
#         [[123, 122, 126],
#          [145, 144, 148],
#          [176, 175, 179],
#          ...,
#          [ 95,  85,  91],
#          [ 96,  86,  92],
#          [ 98,  88,  94]]], dtype=uint8)
#  orig_shape: (1080, 810)
#  path: 'F:\\0_AI\\Books\\Tensorflow\\00_V2\\src\\08\\bus.jpg'
#  probs: None
#  save_dir: 'runs\\pose\\predict2'
#  speed: {'preprocess': 2.999544143676758, 'inference': 50.92024803161621, 'postprocess': 68.99881362915039}]

# %%
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    print(keypoints)
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="result.jpg")  # save to disk
# Out:
# ultralytics.engine.results.Keypoints object with attributes:
#
# conf: tensor([[0.9910, 0.9289, 0.9869, 0.4267, 0.9313, 0.9907, 0.9976, 0.9248, 0.9884, 0.9015, 0.9744, 0.9969, 0.9984, 0.9949, 0.9975, 0.9785, 0.9856],
#         [0.1586, 0.1561, 0.0468, 0.2351, 0.0505, 0.6711, 0.2402, 0.5964, 0.1104, 0.4541, 0.1319, 0.7288, 0.5135, 0.7590, 0.5564, 0.5935, 0.4370],
#         [0.9894, 0.9335, 0.9794, 0.5549, 0.9086, 0.9952, 0.9976, 0.9465, 0.9778, 0.9134, 0.9481, 0.9983, 0.9987, 0.9954, 0.9964, 0.9774, 0.9804],
#         [0.0987, 0.0392, 0.0631, 0.0392, 0.0677, 0.2103, 0.2339, 0.2615, 0.3053, 0.3423, 0.3554, 0.2780, 0.2918, 0.2393, 0.2481, 0.1393, 0.1388]], device='cuda:0')
# data: tensor([[[1.4236e+02, 4.4186e+02, 9.9095e-01],
#          [1.4799e+02, 4.3142e+02, 9.2890e-01],
#          [1.3054e+02, 4.3337e+02, 9.8691e-01],
#          [0.0000e+00, 0.0000e+00, 4.2672e-01],
#          [1.0718e+02, 4.4066e+02, 9.3134e-01],
#          [1.5745e+02, 4.9311e+02, 9.9074e-01],
#          [9.4264e+01, 4.9925e+02, 9.9755e-01],
#          [1.7646e+02, 5.5098e+02, 9.2482e-01],
#          [1.1066e+02, 5.6757e+02, 9.8838e-01],
#          [1.7422e+02, 5.3235e+02, 9.0151e-01],
#          [1.6200e+02, 5.3439e+02, 9.7442e-01],
#          [1.4883e+02, 6.4514e+02, 9.9693e-01],
#          [9.9666e+01, 6.4941e+02, 9.9845e-01],
#          [1.7887e+02, 7.4929e+02, 9.9495e-01],
#          [9.4800e+01, 7.5651e+02, 9.9747e-01],
#          [1.8598e+02, 8.4975e+02, 9.7854e-01],
#          [7.3946e+01, 8.5814e+02, 9.8563e-01]],
#
#         [[0.0000e+00, 0.0000e+00, 1.5855e-01],
#          [0.0000e+00, 0.0000e+00, 1.3879e-01]]], device='cuda:0')
# has_visible: True
# orig_shape: (1080, 810)
# shape: torch.Size([4, 17, 3])
# xy: tensor([[[142.3645, 441.8607],
#          [147.9897, 431.4179],
#          [130.5441, 433.3708],
#          [  0.0000,   0.0000],
#          [107.1834, 440.6561],
#          [157.4519, 493.1139],
#          [ 94.2637, 499.2470],
#          [176.4613, 550.9833],
#          [110.6623, 567.5746],
#          [174.2181, 532.3488],
#          [162.0030, 534.3918],
#          [148.8316, 645.1357],
#          [ 99.6656, 649.4141],
#          [178.8724, 749.2934],
#          [ 94.7997, 756.5117],
#          [185.9790, 849.7501],
#          [ 73.9456, 858.1395]],
#
#         [[  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [809.9744, 487.2144],
#          [  0.0000,   0.0000],
#          [788.5314, 568.7997],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [801.5266, 640.4259],
#          [800.4036, 636.4433],
#          [768.3763, 730.6614],
#          [773.3247, 727.8928],
#          [726.8314, 843.6719],
#          [  0.0000,   0.0000]],
#
#         [[292.5922, 450.8507],
#          [298.3655, 441.7009],
#          [283.1804, 443.3694],
#          [303.7812, 445.5459],
#          [265.3112, 448.9188],
#          [318.1479, 495.4087],
#          [250.9237, 499.1886],
#          [328.8164, 553.8760],
#          [250.5860, 574.8478],
#          [279.4675, 534.9937],
#          [252.4710, 615.7098],
#          [303.4947, 629.9416],
#          [259.3111, 629.5056],
#          [301.0946, 723.6395],
#          [261.1397, 717.7367],
#          [288.2358, 806.2349],
#          [260.5974, 805.2139]],
#
#         [[  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000]]], device='cuda:0')
# xyn: tensor([[[0.1758, 0.4091],
#          [0.1827, 0.3995],
#          [0.1612, 0.4013],
#          [0.0000, 0.0000],
#          [0.1323, 0.4080],
#          [0.1944, 0.4566],
#          [0.1164, 0.4623],
#          [0.2179, 0.5102],
#          [0.1366, 0.5255],
#          [0.2151, 0.4929],
#          [0.2000, 0.4948],
#          [0.1837, 0.5973],
#          [0.1230, 0.6013],
#          [0.2208, 0.6938],
#          [0.1170, 0.7005],
#          [0.2296, 0.7868],
#          [0.0913, 0.7946]],
#
#         [[0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [1.0000, 0.4511],
#          [0.0000, 0.0000],
#          [0.9735, 0.5267],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.9895, 0.5930],
#          [0.9882, 0.5893],
#          [0.9486, 0.6765],
#          [0.9547, 0.6740],
#          [0.8973, 0.7812],
#          [0.0000, 0.0000]],
#
#         [[0.3612, 0.4175],
#          [0.3684, 0.4090],
#          [0.3496, 0.4105],
#          [0.3750, 0.4125],
#          [0.3275, 0.4157],
#          [0.3928, 0.4587],
#          [0.3098, 0.4622],
#          [0.4059, 0.5128],
#          [0.3094, 0.5323],
#          [0.3450, 0.4954],
#          [0.3117, 0.5701],
#          [0.3747, 0.5833],
#          [0.3201, 0.5829],
#          [0.3717, 0.6700],
#          [0.3224, 0.6646],
#          [0.3558, 0.7465],
#          [0.3217, 0.7456]],
#
#         [[0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000],
#          [0.0000, 0.0000]]], device='cuda:0')
