# %% [markdown]
# # 光學文字辨識(Optical Character Recognition, OCR)

# %% [markdown]
# ## 載入相關套件

# %%
# 載入相關套件
import cv2 
import pytesseract
import matplotlib.pyplot as plt

# %% [markdown]
# ## 載入並顯示圖檔

# %%
# 載入圖檔
image = cv2.imread('../images_ocr/receipt.png')

# 顯示圖檔
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %% [markdown]
# ## OCR 辨識

# %%
# 參數設定
custom_config = r'--psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# Welcome to Mel's
# Check #: 0001 12/20/11
# Server: Jesh F 4:38 PM
# Table: 7/1 Guests: 2
# 2 Beef Burgr (€9.95/ea) 19,90
# SIDE: Fries
#
# 1 Bud Light 3.79
# 1 Bud 4.50
# Sub-total 28.19
# Sales Tax 2.50
# TOTAL 30.69
# Balance Due 30.69
#
# Thank you for your patronage! P

# %% [markdown]
# ## 只辨識數字

# %%
# 參數設定，只辨識數字
custom_config = r'--psm 6 outputbase digits'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# 0001 122011
# 4338-
# 71 2
# 29.95 19.90
# 1 3.79
# 1 4.50
# - 28.19
# 2.50
# 30.69
# 30.69

# %% [markdown]
# ## 只辨識有限字元

# %%
# 參數設定白名單，只辨識有限字元
custom_config = r'-c tessedit_char_whitelist=abcdefghijklmnopqrstuvwxyz --psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# elcometoels
# heck
# erverdeshf
# able uests
# eefurgrfea
# fries
#
# udight
# ud
# ubtotal
# alesfax
# a
# alanceue
#
# hankyouforyourpatronage p

# %% [markdown]
# ## 設定黑名單，只辨識有限字元

# %%
# 參數設定黑名單，只辨識有限字元
custom_config = r'-c tessedit_char_blacklist=abcdefghijklmnopqrstuvwxyz --psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# W  M]'
# C #: 0001 12/20/11
# S: J F 4:38 PM
# T: 7/1 G: 2
# 2 B B (€9.95/) 19,90
# SIDE: F
#
# 1 B L 3.79
# 1 B 4.50
# S-] 28.19
# S T 2.50
# TOTAL 30.69
# BI D 30.69
#
# T  é! P

# %% [markdown]
# ## 辨識多國文字

# %% [markdown]
# ## 載入並顯示圖檔

# %%
# 載入圖檔
image = cv2.imread('../images_ocr/chinese.png')

# 顯示圖檔
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %%
# 辨識多國文字，中文繁體、日文及英文
custom_config = r'-l chi_tra+jpn+eng --psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# Tesseract OCR 是目前很盛行的 OCR 軟體,HP 公司於 2005 年開放原始程式碼
# (Open Souree),以CH+開發而成的,可由原始程式碼建置安裝,或直接安裝已建
# 置好的程式,我們採取後者,先自 https://eithub.com/UB-Mannheim/tesseract/wiki
# 下載最新版 exe 檔,直接執行即可,安裝完成後,將安裝路徑下 bin 子目錄放入
# 環境變數 Path 內。若要以 Python 呼叫 Tesseract OCR ,需額外安裝 pytesseract 套
# 件,指令如下:。
#
# pip install pytesseract.

# %% [markdown]
# ## 辨識多國文字

# %% [markdown]
# ## 載入並顯示圖檔

# %%
# 載入圖檔
image = cv2.imread('../images_ocr/chinese_2.png')

# 顯示圖檔
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %%
# 辨識多國文字，中文繁體、日文及英文
custom_config = r'-l chi_tra+jpn+eng --psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# Tesseract OCR 是目前很盛行的OCR 軟體HP公司於2005 年開放原始程式碼(Open
# Source) > DA C++開發而成的,可由原始程式碼建置安裝,或直接安裝已建置好的
# 程式,我們採取後者,先自 https://eithub.com/UB-Mannheim/tesseract/wiki 下載最新
# 版exe 檔,直接執行螞可,安裝完成後,將安裝路徑下bi 子目錄放和人環境變數
# Path 內。若要以 Python 呼叫 Tesseract OCR , 需額外安裝 pytesseract BE FRSA
# 下:
#
# pip install pytesseract

# %% [markdown]
# ## 辨識簡體中文

# %%
# 載入圖檔
image = cv2.imread('../images_ocr/sim_chinese.jpg')
# 顯示圖檔
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# 辨識多國文字，中文、日文及英文
custom_config = r'-l chi_sim+eng --psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# Td lel |           mea lS -
# Ay       oR
# 315   fez  Tt  路   309
#
# j :  WwW     Yuyuan Rd.     Es

# %% [markdown]
# ## 辨識日文

# %%
# 載入圖檔
image = cv2.imread('../images_ocr/japanese.jpg')
# 顯示圖檔
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# 辨識日文
custom_config = r'-l chi_sim+jpn+eng'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# 清潔できれいな港区を
